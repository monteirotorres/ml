# %% [markdown]
# # O que é aprendizagem de máquina?
#
# **Objetivo:** rodar o "olá, mundo" da aprendizagem supervisionada — carregar o Iris, treinar um classificador em poucas linhas e medir seu desempenho em dados que ele não viu. O ciclo mínimo: `dados → treino → avaliação`.

# %%
# bibliotecas base
import numpy as np
import pandas as pd

# Plotly para os gráficos (interativos e leves no Colab)
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
pio.templates.default = "simple_white"

# paleta do curso (a mesma do site)
AZUL, VERMELHO, VERDE = "#3266ad", "#c0392b", "#1a7a4a"
TINTA, SUAVE = "#1c1e15", "#6b7050"

# reprodutibilidade: uma única semente para tudo que é aleatório
SEMENTE = 42
np.random.seed(SEMENTE)

# %% [markdown]
# ## 1. Carregar os dados
#
# O Iris tem 150 flores, 4 características e 3 espécies — o conjunto didático mais famoso da área.

# %%
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
X, y = iris.data, iris.target
print(X.shape, "->", list(iris.target_names))
X.head()

# %% [markdown]
# ## 2. Separar treino e teste
#
# Avaliamos o modelo em dados **nunca vistos** durante o treino — a essência da generalização.

# %%
from sklearn.model_selection import train_test_split

X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3,
                                          random_state=SEMENTE, stratify=y)
print("treino:", X_tr.shape[0], "| teste:", X_te.shape[0])

# %% [markdown]
# ## 3. Treinar e avaliar
#
# Um classificador k-NN em três linhas: `fit` aprende, `score` mede a acurácia no teste.

# %%
from sklearn.neighbors import KNeighborsClassifier

modelo = KNeighborsClassifier(n_neighbors=5)
modelo.fit(X_tr, y_tr)
print("acuracia no teste:", round(modelo.score(X_te, y_te), 3))

# %% [markdown]
# ## Exercícios
#
# **1.** Troque `n_neighbors` para 1 e 50 e relacione com overfitting/underfitting.
#
# **2.** Substitua o k-NN por uma `LogisticRegression`.

# %%
# @title Solução
for k in [1, 5, 50]:
    m = KNeighborsClassifier(n_neighbors=k).fit(X_tr, y_tr)
    print("k =", str(k).rjust(2), "| treino", round(m.score(X_tr, y_tr), 3),
          "| teste", round(m.score(X_te, y_te), 3))
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=500).fit(X_tr, y_tr)
print("LogReg teste:", round(lr.score(X_te, y_te), 3))
