# %% [markdown]
# # O que é aprendizagem de máquina?
#
# **Objetivo:** rodar o "olá, mundo" da aprendizagem supervisionada. Vamos carregar o conjunto Iris, treinar um classificador em poucas linhas e medir seu desempenho em dados que ele não viu — ilustrando o ciclo mínimo de um projeto de ML: `dados → treino → avaliação`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Paleta do curso (idêntica ao site)
INK, PAPER = "#1c1e15", "#fbfdf3"
BLUE, RED, GREEN, MUTED = "#3266ad", "#c0392b", "#1a7a4a", "#6b7050"

plt.rcParams.update({
    "font.family": "serif", "font.size": 12,
    "figure.facecolor": PAPER, "axes.facecolor": PAPER,
    "axes.edgecolor": "#bcc79a", "axes.grid": True,
    "grid.color": "#e4ead0", "grid.linewidth": 0.7,
    "axes.labelcolor": INK, "text.color": INK,
    "xtick.color": MUTED, "ytick.color": MUTED,
})
rng = np.random.default_rng(42)

# %% [markdown]
# ## 1. Carregar os dados
#
# O Iris tem 150 flores, 4 características e 3 espécies. É o conjunto didático mais famoso da área.

# %%
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
X, y = iris.data, iris.target
print(X.shape, '->', iris.target_names)
X.head()

# %% [markdown]
# ## 2. Separar treino e teste
#
# Avaliamos o modelo em dados **nunca vistos** durante o treino — a essência da generalização.

# %%
from sklearn.model_selection import train_test_split

X_tr, X_te, y_tr, y_te = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)
print('treino:', X_tr.shape[0], ' teste:', X_te.shape[0])

# %% [markdown]
# ## 3. Treinar e avaliar
#
# Um classificador k-NN em três linhas. Repare que `fit` aprende e `score` mede a acurácia no teste.

# %%
from sklearn.neighbors import KNeighborsClassifier

modelo = KNeighborsClassifier(n_neighbors=5)
modelo.fit(X_tr, y_tr)
print(f'Acurácia no teste: {modelo.score(X_te, y_te):.3f}')

# %% [markdown]
# ## Exercícios
#
# **1.** Troque `n_neighbors` para 1 e para 50. O que acontece com a acurácia de treino e de teste? Relacione com overfitting/underfitting.
#
# **2.** Substitua o k-NN por uma `LogisticRegression`. O desempenho muda muito?

# %%
# @title Solução (clique para revelar)
for k in [1, 5, 50]:
    m = KNeighborsClassifier(n_neighbors=k).fit(X_tr, y_tr)
    print(f'k={k:2d} | treino={m.score(X_tr,y_tr):.3f} | teste={m.score(X_te,y_te):.3f}')

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=200).fit(X_tr, y_tr)
print('LogReg teste:', round(lr.score(X_te, y_te), 3))
